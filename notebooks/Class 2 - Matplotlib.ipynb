# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib is the best package to produce plots in Python.

# %%
# %pylab inline
# Gives us
# import matplotlib.pyplot as plt
# import numpy as np
# from pylab import *
# from numpy import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# in your scripts you only need
import matplotlib.pyplot as plt

# %% [markdown]
# ## A lot of examples

# %%
from IPython.display import HTML
print 'http://matplotlib.org/gallery.html'
HTML('<iframe src=http://matplotlib.org/gallery.html width=900 height=350></iframe>')
# Out:
# http://matplotlib.org/gallery.html
# <iframe src=http://matplotlib.org/gallery.html width=900 height=350></iframe>

# %% [markdown]
# ## Very basic plots

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# ### Legends

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.xlabel('x Axis')
plt.ylabel('y axis label')
plt.legend(('$t$', '$t^2$', '$t^3$'), loc='best')
plt.show()

# %% [markdown]
# ### Subplots

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()

plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %% [markdown]
# ### Histograms

# %%
mu, sigma = 100, 15
x1 = mu + sigma * np.random.randn(10000)
x2 = 60 + 18 * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x1, 50, normed=1, facecolor='g', alpha=0.50)
n, bins, patches = plt.hist(x2, 50, normed=1, facecolor='r', alpha=0.50)


plt.xlabel('IQ')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(120, .025, r'$\mu=100,\ \sigma=15$')
plt.text(10, .020, r'$\mu=60,\ \sigma=18$')
plt.axis([0, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
n = 1024
X = np.random.normal(0, 1, n)
Y = np.random.normal(0, 1, n)
T = np.arctan2(Y, X)

plt.axes([0.025, 0.025, 0.95, 0.95])
plt.scatter(X, Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5, 1.5)
plt.xticks(())
plt.ylim(-1.5, 1.5)
plt.yticks(())

plt.show()

# %% [markdown]
# ## The object-oriented approach

# %% [markdown]
# So far we have seen examples that call the functions inside `plt` directly. This is good for quick plots, but it gets messy when the plots become more complex.
#
# A better approach is to create axis *objects* and change the properties of those individually.

# %%
# reproducing the first plot
# with the object oriented approach it is more verbose for this simple plot

fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot([1,2,3,4])
ax.set_ylabel('some numbers')

plt.show()

# %%
from numpy import arange, sin, pi

t = arange(0.0, pi, 0.01)

fig = plt.figure(1)  # fig is a Figure object

ax1 = fig.add_subplot(211)  # add a subplot to fig
                            # the syntax is add_subplot(number_subplot_lines, number_subplot_columns, this_subplot)
                            # ax1 is a subplot object with methods such as plot
    
ax1.plot(t, sin(2*pi*t))
ax1.set_xticks((0, 1, 2), ('0', '1', '2'))
ax1.grid(True)
ax1.set_xlim(0, pi)
ax1.set_ylim(-2,2)
ax1.set_ylabel('Hz')
ax1.set_title('A sine wave or two')


for label in ax1.get_xticklabels():
    label.set_color('r')


ax2 = fig.add_subplot(212)  # add another subplot
ax2.plot(t, sin(2*2*pi*t))
ax2.grid(False)
ax2.axis((0, pi, -2, 2))
ax2.set_xticks((0, pi/2, pi), ('0', '1', '2'))
#l = ax2.set_xlabel('XX axis')
#l.set_color('g')
#l.set_fontsize('xx-large')

plt.show()

# %% [markdown]
# ### Ticks (user defined things on axis) and XKCD

# %%
t = arange(0, 3.5, 0.1)

with plt.xkcd():  # For fun
    fig = plt.figure(1)
    ax = fig.add_subplot(111)

    ax.plot(t, np.exp(t), linewidth=5, color='r', alpha=0.7)
    ax.set_xticks((0, 1, 2), ('0', '1', '2'))
    ax.set_xlim(0, pi)
    ax.set_title('Christmas spirit', size='x-large', color='g')
    ax.hlines([2, 5, 10, 20], 0, 5, color='g', linestyle='--', alpha=0.5)
    plt.xticks((0.5, 1.5, 2.5, 3.45), ('October', 'November', 'December', 'Christmas'), rotation=315, size='xx-large', color='g')
    plt.yticks((2, 5, 10, 20), ('Not at all', 'Listen to songs', 'Baking cookies', 'GIFTS!!!'), size='x-large', color='g')
    show()

# %% [markdown]
# ## Seaborn

# %%
mention it!
# Out:
#   File "<ipython-input-2-31e201927a29>", line 1
#     mention it!
#              ^
# SyntaxError: invalid syntax
